# %% [markdown]
# ![5-day-gen-ai-17(2).png](attachment:b8e7ebf8-c989-4d34-a8a9-02fa0eedabe5.png)

# %% [markdown]
# [Vibey and the Rainbow Glitch](https://www.kaggle.com/datasets/norikokono/vibey-and-the-rainbow-glitch)
