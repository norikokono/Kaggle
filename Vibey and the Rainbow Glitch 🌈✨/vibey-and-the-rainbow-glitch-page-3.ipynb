# %% [markdown]
# ![Screenshot (198).png](attachment:eaa83caa-f128-40f5-83c7-e7ca2d2f30a3.png)

# %% [markdown]
# [Vibey and the Rainbow Glitch: Extended 🌈](https://www.kaggle.com/datasets/norikokono/vibey-and-the-rainbow-glitch-extended)
